# %%
from sentence_transformers import SentenceTransformer, util
from scipy import spatial
import pandas as pd
sentences = ["This is a Norwegian boy", "Dette er en norsk gutt"]

model = SentenceTransformer('NbAiLab/nb-sbert-base')
embeddings = model.encode(sentences)
embeddings
# Out:
# array([[ 1.4281031 ,  0.39518782,  0.06262632, ...,  1.1759279 ,
#          0.59693366, -0.12693629],
#        [ 1.4975808 , -0.52666426, -0.03449104, ...,  1.3204104 ,
#          0.85494673,  0.14108105]], dtype=float32)

# %%
# Compute cosine-similarities with sentence transformers
cosine_scores = util.cos_sim(embeddings[0],embeddings[1])
print(cosine_scores)

# Compute cosine-similarities with SciPy
scipy_cosine_scores = 1 - spatial.distance.cosine(embeddings[0],embeddings[1])
print(scipy_cosine_scores)
# Out:
# tensor([[0.8250]])
# 0.8250487446784973

# %%
from keybert import KeyBERT
from bertopic import BERTopic
kw_model = KeyBERT(model=model)
model = BERTopic(embedding_model=model, verbose=True)

# %%
# from sklearn.datasets import fetch_20newsgroups

# docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']
# docs = docs[:1000]

# %%
df = pd.read_csv('Data_NER.csv')
df.dropna(inplace=True)

# %%
# Create a list with all docs from df.Subtitle
docs = df.Subtitle.tolist()

# %%
model.fit(docs)
# Out:
# Batches: 100%|██████████| 517/517 [19:43<00:00,  2.29s/it]
# 2022-12-07 17:16:12,756 - BERTopic - Transformed documents to Embeddings
# 2022-12-07 17:16:34,703 - BERTopic - Reduced dimensionality
# 2022-12-07 17:16:38,028 - BERTopic - Clustered reduced embeddings

# %%
model.visualize_topics()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\mathi\Prosjekter\Barcelona\HLE\HLE-Project\venv\lib\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File c:\Users\mathi\Prosjekter\Barcelona\HLE\HLE-Project\venv\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\mathi\Prosjekter\Barcelona\HLE\HLE-Project\venv\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'customdata': array([[0, 'ukraina | russiske | russland | putin | vladimir', 3020],
#                                    [1, 'hun | da | fikk | legene | hadde', 431],
#                                    [2, 'dronning | prins | prinsesse | elizabeth | kong', 429],
#                                    ...,
#                                    [160, 'sverige | rangers | sang | haaland | scoret', 10],
#                                    [161, 'kvinnehelse | kvinner | gjerrig | selvsagt | problemet', 10],
#                                    [162, 'instagram | konto | innholdet | fjernet | lydon', 10]],
#                                   dtype=object),
#               'hovertemplate': ('<b>Topic %{customdata[0]}</b><' ... '[1]}<br>Size: %{customdata[2]}'),
#               'legendgroup': '',
#               'marker': {'color': '#B0BEC5',
#                          'line': {'color': 'DarkSlateGrey', 'width': 2},
#                          'size': array([3020,  431,  429,  278,  273,  263,  252,  243,  202,  184,  172,  164,
#                                          159,  156,  153,  135,  108,   98,   97,   95,   92,   81,   80,   80,
#                                           77,   77,   76,   76,   75,   74,   74,   73,   72,   71,   69,   67,
#                                           65,   64,   63,   60,   58,   58,   46,   45,   43,   42,   40,   38,
#                                           38,   38,   37,   37,   37,   37,   35,   34,   33,   33,   32,   31,
#                                           31,   31,   31,   30,   30,   30,   30,   29,   29,   28,   28,   28,
#                                           27,   27,   27,   26,   26,   26,   26,   26,   24,   24,   23,   23,
#                                           23,   23,   23,   22,   22,   21,   21,   20,   20,   20,   20,   19,
#                                           19,   19,   18,   18,   18,   18,   18,   18,   18,   18,   18,   17,
#                                           17,   17,   17,   16,   16,   16,   16,   16,   16,   16,   16,   16,
#                                           15,   15,   14,   14,   14,   14,   14,   14,   14,   13,   13,   13,
#                                           13,   13,   13,   13,   13,   13,   13,   13,   13,   13,   12,   12,
#                                           12,   12,   12,   12,   12,   12,   11,   11,   11,   11,   11,   11,
#                                           11,   11,   10,   10,   10,   10,   10], dtype=int64),
#                          'sizemode': 'area',
#                          'sizeref': 1.8875,
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array([-12.523661 ,   6.9906383,  -2.2813501,   9.037407 , -12.458778 ,
#                             9.340235 ,   7.735244 ,  -8.893271 ,   6.9931993,  -6.518017 ,
#                             9.074452 ,  11.743706 ,  12.396689 ,  -1.8386   ,  17.600796 ,
#                            -8.85086  ,  11.753031 ,   3.0395494,  -8.869422 ,   1.9918251,
#                            -6.661465 ,  -6.607345 ,   1.068698 ,  -6.3686705,   2.2704122,
#                             5.6240664,  -6.356536 ,   2.270304 ,   2.009767 , -10.996573 ,
#                           -11.058616 ,   6.97903  ,  17.601318 ,   7.7368183,  12.475178 ,
#                             3.7034104,  -2.2424934, -11.23368  ,   9.446392 ,   9.47271  ,
#                            -2.2225585,   8.683387 ,   1.0686935,  -1.8706868,   9.010648 ,
#                             3.7526724,  -2.1695848,   3.9150732,   1.7574418,   1.9124272,
#                            11.800432 ,  -1.8457732,  -1.9502629,  -6.8411374,   4.718242 ,
#                            14.173911 ,  13.551657 ,   9.076509 ,  -2.1294115,  11.809672 ,
#                             3.197926 , -11.182439 ,  13.525041 ,  13.570939 ,  14.084999 ,
#                            14.023926 ,  -1.7711654,   8.697413 , -11.045719 ,  -1.7253621,
#                           -12.457773 ,  -1.8557554,  -2.3040116,  12.411415 ,  -6.8894286,
#                            -9.38681  ,   3.2160375,  -6.8541417,   1.0686834,   1.5884428,
#                             7.7628756,  -1.8693832, -11.157293 ,   3.7920566,   4.9528275,
#                            -9.259078 ,   5.645557 ,  12.680742 ,  -9.305865 ,   2.058288 ,
#                            -9.256727 ,   5.678567 ,  11.743236 ,   8.467202 ,  15.628734 ,
#                            -7.010959 ,   8.697383 ,   3.7922096,  10.097442 ,  -7.052299 ,
#                            11.821697 ,  -3.1498246,   3.6719859,   3.12659  ,  11.803556 ,
#                            -9.366106 ,   7.7259846,  -9.195533 ,  -1.7769763,  10.081331 ,
#                             5.7950015,   1.6980534,   7.046185 ,  13.466742 ,  11.842725 ,
#                            15.628922 ,  -3.1498468,  -9.329812 ,   1.5860128,   1.8524824,
#                            14.246646 ,   4.7192154,  11.213577 ,   3.2985394,  11.90724  ,
#                            12.392641 ,  -1.54934  ,   3.457032 ,   8.719202 ,   1.4489275,
#                            14.076896 ,   3.544022 ,   1.7920382,   3.571657 ,   9.994213 ,
#                             4.9746027,  -9.1218815,  -1.4678562,  -2.314155 ,  11.171096 ,
#                            12.634125 , -11.233808 ,  13.974977 ,   1.8524313,  11.677526 ,
#                            14.090624 ,   2.027592 ,  -1.4815636,  -9.267526 ,  11.81638  ,
#                             8.461768 ,  -9.208944 ,   4.9824924,  11.278847 ,  14.060633 ,
#                            14.154999 ,   7.0197515,   5.6329494,   7.0470576,   9.365546 ,
#                             9.335629 ,   1.7611295,   3.3640027], dtype=float32),
#               'xaxis': 'x',
#               'y': array([  6.220003  ,  -1.7024896 ,   3.4757092 ,   0.8186511 ,   6.158245  ,
#                           -14.488976  ,   9.082548  ,  -7.607484  ,  -1.7045246 ,   3.7709558 ,
#                             0.8369984 ,  -4.9467263 ,  -4.256498  ,   8.813732  ,  -0.5444247 ,
#                            -7.5646424 ,  -4.4550595 , -11.873067  ,  -7.5830035 ,   0.77918166,
#                             3.6267457 ,   3.680971  ,  -4.792559  ,   3.921826  ,   2.2430968 ,
#                            16.560661  ,   3.9349015 ,   2.2428768 ,   0.79269665,  -2.4422832 ,
#                            -2.3804574 ,  -1.6904874 ,  -0.54497015,   9.084843  ,  -4.231161  ,
#                           -12.320984  ,   3.324978  ,  -2.2025847 , -14.383346  , -14.356782  ,
#                            12.426205  ,   0.62728417,  -4.792601  ,  12.061373  ,   0.78621376,
#                           -11.920239  ,  12.371981  , -11.766701  ,   6.5664477 ,   6.12201   ,
#                             6.5056105 ,  12.0203905 ,  12.112809  ,   8.482145  ,   1.8904648 ,
#                             3.308406  ,   9.731716  ,   0.8575837 ,   3.361172  ,   6.4958405 ,
#                           -11.984323  ,  -2.2554274 ,   9.757641  ,   9.71289   ,   3.3971643 ,
#                            14.576174  ,   8.746583  ,   5.213737  ,  -2.393549  ,   3.248353  ,
#                             6.157715  ,  12.026399  ,   3.397093  ,  -4.257904  ,   8.429694  ,
#                             2.890356  , -12.347497  ,   8.4649105 ,  -4.7925115 ,   6.624632  ,
#                             9.110426  ,   8.844716  ,  -2.2801936 ,   6.7534757 ,  11.898122  ,
#                             3.015946  ,  16.582558  ,  -3.953194  ,   2.9704318 ,   5.9152226 ,
#                            -7.9711857 ,  16.615849  ,  -4.9063125 ,   0.7760299 ,   7.2884016 ,
#                             8.307006  ,   5.213667  ,   6.753657  ,  10.5768175 ,   8.266118  ,
#                            -4.3555813 ,  15.739174  , -12.271938  , -12.365966  ,  -4.6905894 ,
#                             2.9105208 ,   9.073571  ,  -7.9129725 ,   3.3023841 ,  10.560468  ,
#                            16.731878  ,   5.9982142 ,   2.000241  ,   9.8148    ,  -4.3330956 ,
#                             7.288383  ,  15.739243  ,  -8.044693  ,   6.65263   ,   9.194326  ,
#                             3.2320342 ,   1.890472  ,  -3.9405174 , -11.664033  ,  -4.4993367 ,
#                            -4.4613843 ,   3.1357033 , -11.987093  ,   0.75022334,   6.5546913 ,
#                             3.4053586 , -11.833023  ,   6.1563983 , -12.0320835 ,  10.473404  ,
#                            11.8762    ,  -7.838303  ,   3.0761447 ,   3.5260909 ,  -3.878058  ,
#                            -4.004804  ,  -2.2030234 ,  14.527401  ,   9.194773  ,  -4.3483133 ,
#                            14.641684  ,   5.9509115 ,   3.0760016 ,  -7.9837933 ,   6.48914   ,
#                             0.77782166,  -7.926402  ,  11.868332  ,  -3.988661  ,  14.612183  ,
#                             3.324678  ,   2.0287676 ,  16.57041   ,   2.0007455 , -14.463814  ,
#                           -14.493937  ,   6.0393834 , -11.575053  ], dtype=float32),
#               'yaxis': 'y'}],
#     'layout': {'annotations': [{'showarrow': False,
#                                 'text': 'D1',
#                                 'x': -14.402209758758545,
#                                 'y': 1.2868165016174302,
#                                 'yshift': 10},
#                                {'showarrow': False,
#                                 'text': 'D2',
#                                 'x': 2.9196531772613525,
#                                 'xshift': 10,
#                                 'y': 19.241660022735594}],
#                'height': 650,
#                'hoverlabel': {'bgcolor': 'white', 'font': {'family': 'Rockwell', 'size': 16}},
#                'legend': {'itemsizing': 'constant', 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'shapes': [{'line': {'color': '#CFD8DC', 'width': 2},
#                            'type': 'line',
#                            'x0': 2.9196531772613525,
#                            'x1': 2.9196531772613525,
#                            'y0': -16.668027019500734,
#                            'y1': 19.241660022735594},
#                           {'line': {'color': '#9E9E9E', 'width': 2},
#                            'type': 'line',
#                            'x0': -14.402209758758545,
#                            'x1': 20.24151611328125,
#                            'y0': 1.2868165016174302,
#                            'y1': 1.2868165016174302}],
#                'sliders': [{'active': 0,
#                             'pad': {'t': 50},
#                             'steps': [{'args': [{'marker.color': [['red',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5']]}],
#                                        'label': 'Topic 0',
#                                        'method': 'update'},
#                                       {'args': [{'marker.color': [['#B0BEC5',
#                                                                   'red', '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5']]}],
#                                        'label': 'Topic 1',
#                                        'method': 'update'},
#                                       {'args': [{'marker.color': [['#B0BEC5',
#                                                                   '#B0BEC5', 'red',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
# ...
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5', 'red',
#                                                                   '#B0BEC5']]}],
#                                        'label': 'Topic 161',
#                                        'method': 'update'},
#                                       {'args': [{'marker.color': [['#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   '#B0BEC5',
#                                                                   'red']]}],
#                                        'label': 'Topic 162',
#                                        'method': 'update'}]}],
#                'template': '...',
#                'title': {'font': {'color': 'Black', 'size': 22},
#                          'text': '<b>Intertopic Distance Map',
#                          'x': 0.5,
#                          'xanchor': 'center',
#                          'y': 0.95,
#                          'yanchor': 'top'},
#                'width': 650,
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [-14.402209758758545, 20.24151611328125],
#                          'title': {'text': ''},
#                          'visible': False},
#                'yaxis': {'anchor': 'x',
#                          'domain': [0.0, 1.0],
#                          'range': [-16.668027019500734, 19.241660022735594],
#                          'title': {'text': ''},
#                          'visible': False}}
# })

# %%
topic_info = model.get_topic_info()
# Get topic info where Name includes 'haaland'

topic_info[topic_info['Name'].str.lower().str.contains('haaland')]
# Out:
#      Topic  Count                              Name
# 6        5    263       5_haaland_erling_braut_city
# 161    160     10  160_sverige_rangers_sang_haaland

# %%
topic_info
# Out:
#      Topic  Count                                       Name
# 0       -1   5507                             -1_på_en_og_er
# 1        0   3020          0_ukraina_russiske_russland_putin
# 2        1    431                       1_hun_da_fikk_legene
# 3        2    429       2_dronning_prins_prinsesse_elizabeth
# 4        3    278                 3_drept_mann_siktet_kvinne
# ..     ...    ...                                        ...
# 159    158     10  158_ekskona_grunlegger_amazon_skodesigner
# 160    159     10       159_janne_andersson_straffe_sveriges
# 161    160     10           160_sverige_rangers_sang_haaland
# 162    161     10   161_kvinnehelse_kvinner_gjerrig_selvsagt
# 163    162     10      162_instagram_konto_innholdet_fjernet
#
# [164 rows x 3 columns]

# %%
asd = model.transform(['hello world', 'hallo verden'])
# Out:
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.41it/s]
# 2022-12-07 17:36:33,586 - BERTopic - Reduced dimensionality
# 2022-12-07 17:36:33,588 - BERTopic - Predicted clusters

# %%
asd
# Out:
# ([18, 7], array([1.        , 0.71400195]))

# %%
model.get_topic(7)
# Out:
# [('jeg', 0.06034656787040656),
#  ('meg', 0.04140010768785461),
#  ('ikke', 0.020729475707607532),
#  ('dette', 0.01938208132402451),
#  ('hva', 0.015338045145589568),
#  ('det', 0.014283259285607794),
#  ('hadde', 0.01293093760318717),
#  ('veldig', 0.012576391548908291),
#  ('min', 0.012536958699112668),
#  ('si', 0.012053349978694037)]

# %%
model_results = model.transform(docs)
# Out:
# Batches: 100%|██████████| 517/517 [19:39<00:00,  2.28s/it]
# 2022-12-07 18:02:03,006 - BERTopic - Reduced dimensionality
# 2022-12-07 18:02:03,580 - BERTopic - Predicted clusters

# %%
df['BERT_topic_num'] = -1
df['BERT_topic_prob'] = 0
for i in range(len(model_results[0])):
    group = model_results[0][i]
    prob = model_results[1][i]
    df['BERT_topic_num'][i] = group
    df['BERT_topic_prob'][i] = prob

# %%
df
# Out:
#        Unnamed: 0                                               Link  \
# 0               0  https://www.dagbladet.no/nyheter/kaotisk-nytta...
# 1               1  https://www.dagbladet.no/tema/fra-singel-til-d...
# 2               2  https://www.dagbladet.no/tema/strom-nytt-fra-j...
# 3               3  https://www.dagbladet.no/tema/anders-kvitt-mag...
# 4               4  https://www.dagbladet.no/nyheter/taus-om-overg...
# ...           ...                                                ...
# 16529       17417  https://www.dagbladet.no/sport/hjerteskjaerend...
# 16530       17418  https://www.dagbladet.no/nyheter/venter-stromh...
# 16531       17419  https://www.dagbladet.no/kjendis/betatt-av-hol...
# 16532       17420  https://www.dagbladet.no/tema/fra-sexlei-til-v...
# 16533       17421  https://www.dagbladet.no/tema/lindas-skrekk-te...
#
#                                     Headline Category  \
# 0      kaotisk nyttarsnatt   ute av kontroll  nyheter
# 1                  fra singel til damemagnet     tema
# 2                      strom nytt fra januar     tema
# 3      anders kvitt magefettet i superfart 1     tema
# 4                       taus om overgrepsdom  nyheter
# ...                                      ...      ...
# 16529               hjerteskjaerende melding    sport
# 16530              venter stromhopp i vinter  nyheter
# 16531            betatt av hollywood stjerne  kjendis
# 16532          fra sexlei til vanvittig tent     tema
# 16533       lindas skrekk telefon frysninger     tema
#
#                                                 Subtitle  \
# 0      Det har vært en hektisk nyttårsnatt for politi...
# 1      Ekspertenes beste råd til hvordan du blir attr...
# 2      Nye boligregler, bedre jobbpensjon og dyrere f...
# 3      - Hvis folk bare visste hvor enkelt det er, ha...
# 4      Trump ønsket «henne alt godt» i fjor sommer. N...
# ...                                                  ...
# 16529  Spania og Tyskland spilte 1-1. Det betyr at sp...
# 16530  Lavere temperaturer og lite vind i Europa, kan...
# 16531  Ifølge ei ny bok var kong Charles litt forelsk...
# 16532  Kvinnen ville ikke ha sex lenger. Så gjorde ma...
# 16533  Linda aner fred og ingen fare, da telefonen ri...
#
#                                                 Keywords  \
# 0                                               nyheter
# 1                                kjæreste,dating,singel
# 2                          metadz,økonomi,pensjon,skatt
# 3          magefett,vektnedgang,kosthold,styrketrening,
# 4      donald trump,ghislaine maxwell,utenriks,nyhete...
# ...                                                  ...
# 16529                                    qatar-vm,sport
# 16530               strømpriser,været,nyheter,innenriks
# 16531   forelsket,kjendis,kong charles,barbra streisand
# 16532                                  xavierx,kåt,sex,
# 16533                         hjertestans,dødsfall,sorg
#
#                                        subtitle_entities  \
# 0                                                     {}
# 1                                                     {}
# 2                                                     {}
# 3                                {'Anders Muren': 'PER'}
# 4      {'Trump': 'PER', 'Ghislaine Maxwell': 'PER', '...
# ...                                                  ...
# 16529  {'Spania': 'ORG', 'Tyskland': 'ORG', 'Qatar - ...
# 16530                                  {'Europa': 'LOC'}
# 16531                                 {'Charles': 'PER'}
# 16532                                                 {}
# 16533                                   {'Linda': 'PER'}
#
#                                        keywords_entities  BERT_topic_num  \
# 0                                                     {}              -1
# 1                                                     {}              13
# 2                                                     {}              -1
# 3                                                     {}               8
# 4      {'donald trump': 'PER', 'usa': 'LOC', 'jeffrey...              -1
# ...                                                  ...             ...
# 16529                                                 {}              -1
# 16530                                                 {}              48
# 16531                                                 {}               2
# 16532                                                 {}              -1
# 16533                                                 {}               1
#
#        BERT_topic_prob
# 0             0.000000
# 1             0.364456
# 2             0.000000
# 3             1.000000
# 4             0.000000
# ...                ...
# 16529         0.000000
# 16530         0.958357
# 16531         1.000000
# 16532         0.000000
# 16533         1.000000
#
# [16534 rows x 10 columns]

# %%
df.to_csv('Data_NER_BERT.csv', index=False)
